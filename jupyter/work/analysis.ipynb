# %%
import pymysql
from pandas.io import sql
sql_str = "select *  from abilities"
connection = pymysql.connect(host="db", db="analysis", user="root", password="password", charset='utf8', cursorclass=pymysql.cursors.DictCursor)
df = sql.read_sql(sql_str, connection)
df
# Out:
#     ability_id        item                                        description
# 0            1    オフェンスセンス  1対1の局面でプレーの精度に影響を及ぼす数値。相手のディフェンスの数値と相殺し、上回れば相手...
# 1            2   ボールコントロール                         トラップやドリブルなどのボールを操る技術を表す数値。
# 2            3        ドリブル  ドリブルのテクニックを表した数値。この数値が高い選手は細かいドリブルが可能で、切り返しが素早...
# 3            4     グランダーパス           低い弾道のパス。この数値が高いほど素早く正確なグランダーパスを出すことができる。
# 4            5       フライパス           高い弾道(浮き球)のパス。この数値が高いほど正確なフライパスを出すことができる。
# 5            6         カーブ  フリーキックやコーナーキックでボールを蹴る際に曲がったボールを蹴ることができる。この数値が高...
# 6            7       ヘディング  ヘディング全般の精度を表した数値。この数値が高いと、叩き込む以外に擦るヘディングや落とすパス...
# 7            8   ディフェンスセンス  オフェンス同様に局面での強さを表した数値。この数値が大きいほど相手に競り勝ち、ボールを奪える...
# 8            9       ボール奪取                            相手のパスコースを読みボールをカットする能力。
# 9           10        キック力  シュートのときだけでなく、いろいろなキックの力に影響する数値。この値が高ければ高いほど、勢い...
# 10          11        スピード  ボールを持たずに走ったの速さを表す。ダッシュドリブルの最高速度や、ＣＰＵがボールを追いかける...
# ...
